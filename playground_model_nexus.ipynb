# %%
import yaml
import subprocess

# %%
data_file='workflow/data.txt'
processed_datafile='workflow/processed_data.txt'
processed_model='workflow/processed_model_BCNexus.txt'
gurobi_result_file='Gurobi_run/gurobi.sol'
LP_file='workflow/LP_file/BCNexus.lp'

# %% [markdown]
# ## Create LP file using GLPK

# %%
cmd_lp_create= f"glpsol -m {processed_model} -d {processed_datafile} --wlp {LP_file} --check"
subprocess.run(cmd_lp_create, shell=True, text=True)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  -m workflow/processed_model_BCNexus.txt -d workflow/processed_data.txt --wlp
#  workflow/LP_file/BCNexus.lp --check
# Reading model section from workflow/processed_model_BCNexus.txt...
# 226 lines were read
# Reading data section from workflow/processed_data.txt...
# workflow/processed_data.txt:385905: warning: final NL missing before end of file
# 385905 lines were read
# Generating cost...
# Generating CAa1_TotalNewCapacity...
# Generating CAa2_TotalAnnualCapacity...
# Generating CAa3_TotalActivityOfEachTechnology...
# Generating CAa4_Constraint_Capacity...
# Generating CAa5_TotalNewCapacity...
# Generating CAb1_PlannedMaintenance...
# Generating EBa9_EnergyBalanceEachTS3...
# Generating EBa10_EnergyBalanceEachTS4...
# Generating EBa11_EnergyBalanceEachTS5...
# Generating EBb4_EnergyBalanceEachYear4...
# Generating Acc3_AverageAnnualRateOfActivity...
# Generating S5_and_S6_StorageLevelYearStart...
# ...

# %% [markdown]
# ## GUROBI

# %% [markdown]
# ### Solve Model

# %%
LP_file
# Out:
# 'workflow/LP_file/BCNexus.lp'

# %%
print(f"Running Gurobi Solver with LP file: {LP_file} and the targeted ResultFile: {gurobi_result_file}")
cmd_solve_model_gurobi= f"gurobi_cl ResultFile={gurobi_result_file} {LP_file}"
subprocess.run(cmd_solve_model_gurobi, shell=True, text=True)
# Out:
# Running Gurobi Solver with LP file: workflow/LP_file/BCNexus.lp and the targeted ResultFile: Gurobi_run/gurobi.sol
# Set parameter Username
# Set parameter LogFile to value "gurobi.log"
# Using license file /localhome/mei3/gurobi.lic
# Academic license - for non-commercial use only - expires 2025-01-18
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
# Copyright (c) 2024, Gurobi Optimization, LLC
#
# Read LP format model from file workflow/LP_file/BCNexus.lp
# Reading time = 1.24 seconds
# cost: 293580 rows, 322683 columns, 3366258 nonzeros
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 32 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 293580 rows, 322683 columns and 3366258 nonzeros
# Model fingerprint: 0x6221a422
# Coefficient statistics:
#   Matrix range     [3e-08, 8e+03]
#   Objective range  [2e-05, 1e+04]
#   Bounds range     [0e+00, 0e+00]
# ...

# %%
otoole_yaml_file='workflow/config/otoole_config.yaml'

# %%
gurobi_result_file

# %%
print(f"Initiating otoole to extract results from Gurobi Solver using Datafile : {data_file} , config file: {otoole_yaml_file} and the targeted Model_Kotzur/results")
otoole_results_ = f"otoole results gurobi csv {gurobi_result_file} Model_Kotzur/results datafile {data_file} {otoole_yaml_file}"
subprocess.run(otoole_results_, shell=True, text=True)
# Out:
# Initiating otoole to extract results from Gurobi Solver using Datafile : workflow/data.txt , config file: workflow/config/otoole_config.yaml and the targeted Model_Kotzur/results
# AssertionError:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 print(f"Initiating otoole to extract results from Gurobi Solver using Datafile : {data_file} , config file: {otoole_yaml_file} and the targeted Model_Kotzur/results")
#       2 otoole_results_ = f"otoole results gurobi csv {gurobi_result_file} Model_Kotzur/results datafile {data_file} {otoole_yaml_file}"
# ----> 3 subprocess.run(otoole_results_, shell=True, text=True)
#
# File ~/miniconda3/envs/bc_combined_model/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# ...

# %%
gurobi_model_run_cml=f"gurobi_cl Result_file={gurobi_result_file} {LP_file}"

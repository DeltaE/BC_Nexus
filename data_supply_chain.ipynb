# %%
import pandas as pd

# %%
specific_demand_profile=pd.read_csv('datapackage/REF_datapackage_template/SpecifiedDemandProfile.csv')

# %%
mask1=specific_demand_profile.VALUE>0
mask2=specific_demand_profile.YEAR==2020
specific_demand_profile[mask1][mask2].FUEL.unique()
# Out:
# /tmp/ipykernel_1145985/2609998490.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   specific_demand_profile[mask1][mask2].FUEL.unique()
# array(['AGRELCB02', 'COMELCB02', 'INDELCB02', 'RESELCB02', 'TRAELCB02'],
#       dtype=object)

# %%
specific_demand_profile[mask1][mask2]
# Out:
# /tmp/ipykernel_1145985/1011738341.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   specific_demand_profile[mask1][mask2]
#       REGION       FUEL TIMESLICE  YEAR  VALUE
# 8    REGION1  AGRELCB02     SEA1D  2020   0.15
# 9    REGION1  AGRELCB02     SEA1N  2020   0.08
# 10   REGION1  AGRELCB02     SEA2D  2020   0.16
# 11   REGION1  AGRELCB02     SEA2N  2020   0.07
# 12   REGION1  AGRELCB02     SEA3D  2020   0.12
# 13   REGION1  AGRELCB02     SEA3N  2020   0.13
# 14   REGION1  AGRELCB02     SEA4D  2020   0.13
# 15   REGION1  AGRELCB02     SEA4N  2020   0.16
# 56   REGION1  COMELCB02     SEA1D  2020   0.15
# 57   REGION1  COMELCB02     SEA1N  2020   0.08
# 58   REGION1  COMELCB02     SEA2D  2020   0.16
# 59   REGION1  COMELCB02     SEA2N  2020   0.07
# 60   REGION1  COMELCB02     SEA3D  2020   0.12
# 61   REGION1  COMELCB02     SEA3N  2020   0.13
# 62   REGION1  COMELCB02     SEA4D  2020   0.13
# 63   REGION1  COMELCB02     SEA4N  2020   0.16
# ...

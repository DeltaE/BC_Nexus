# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import yaml

# %%
def load_config(file_path):

    with open(file_path, 'r') as file:
        data = yaml.safe_load(file)

    return data

# %% [markdown]
# ## Tables

# %%
tables_list = [t for t in requests.get(url+"/tables").json()]
tables_list

# %%
from bcnexus.clews import livestock as bcnexus_lvs
# Out:
#  └ Module Activated: 'sets_n_ratios'
#
# ...
#
#
# ...
#
#
# ...

# %%
bcnexus_lvs.main()
# Out:
#  └ Creating Livestock Technologies and Fuels from model structure....
#   └ Livestock Technologies and Fuels Created.
#  └ Creating Livestock SETs....
#   └ updating Livestock SET : 'TECHNOLOGY'
#   └ updating Livestock SET : 'FUEL'
#   └ Livestock SETs updated.
#  └ Livestock Ratios updated.
#  └ Writing SETs to SETs-test
#   └ Writing YEAR to SETs-test/YEAR.csv
#   └ Writing EMISSION to SETs-test/EMISSION.csv
#   └ Writing REGION to SETs-test/REGION.csv
#   └ Writing TECHNOLOGY to SETs-test/TECHNOLOGY.csv
#   └ Writing FUEL to SETs-test/FUEL.csv
#   └ Writing MODE_OF_OPERATION to SETs-test/MODE_OF_OPERATION.csv
#   └ Writing Input Activity Ratios to SETs-test/InputActivityRatio.csv
#   └ Writing Output Activity Ratios to SETs-test/OutputActivityRatio.csv
#   └ Checking MODE_OF_OPERATIONS at SETs-test
#   └─ Updating MODE_OF_OPERATIONS ...
#   └─ Added 2 new modes to SETs-test/MODE_OF_OPERATION.csv

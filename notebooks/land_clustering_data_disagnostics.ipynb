# %%
import pandas as pd

# %%
OAR_new=pd.read_csv("data/clews_data/clews_build_data/input_csvs/OutputActivityRatio.csv")

# %%
OAR_legacy=pd.read_csv("models/csv_template/OutputActivityRatio.csv")

# %%
OAR_new[OAR_new.FUEL.str.startswith('CRP')].VALUE.min()
# Out:
# np.float64(0.00013)

# %%
OAR_legacy[OAR_legacy.FUEL.str.startswith('CRP')].VALUE.min()
# Out:
# np.float64(3.8e-07)

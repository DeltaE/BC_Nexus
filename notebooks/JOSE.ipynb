# %%
from bcnexus.clews.builder import BuildModel
# Out:
#  └ Module Activated: 'sets_n_ratios'

# %%
args={
    'combined_model_config_path': 'config/config.yaml',
    'scenario': 'Base_CNZ',
    'storage_algorithm': 'Kotzur',
    'clustering_attributes': {
        'hour_grouping': 4,
        'n_clusters': 4
    }

}

NexusBuilder=BuildModel(**args) # loading the class instance
# Out:
# └ Initiating CLEWs Model Builder for Base_CNZ scenario with Kotzur storage algorithm
#  └ Extracting class attributes e.g. directories, static values/ranges, constants etc.
#  └ Checked and copied missing CSV files from data/clews_data/csv_template to data/clews_data/inputs_csv

# %% [markdown]
# # steps for Updating Sets and params

# %% [markdown]
# - Step 1 : Copies the Land Cluster Data (as a starting point)

# %% [markdown]
# #### inside _BuilderModel.build.build_SETs_and_rations_ method

# %%
NexusBuilder.get_LandCluster_data() # updating sets and parameters

# %% [markdown]
# - step 2

# %%
import pandas as pd
from pathlib import Path
import bcnexus.utils as utils

# %%
FUEL_set_file_path=Path(NexusBuilder.SETs_save_to / 'FUEL.csv')
FUEL_df=pd.read_csv(FUEL_set_file_path)

# %%
FUEL_df
# Out:
#         VALUE
# 0      INDDSL
# 1         DSL
# 2      INDBIO
# 3         BIO
# 4      INDNGS
# ..        ...
# 130  LBEFCBC1
# 131    LVSMIL
# 132   LMILBC1
# 133   LND4PWR
# 134    CO2CCS
#
# [135 rows x 1 columns]

# %%
new_fuels = ['LND4PWR', 'HDG', 'CO2CCS',]
for fuel in new_fuels:
    if fuel not in FUEL_df['VALUE'].values:
        new_row = pd.DataFrame([{'VALUE': fuel}])
        FUEL_df = pd.concat([FUEL_df, new_row], ignore_index=True)
        FUEL_df.to_csv(FUEL_set_file_path, index=False)
        utils.print_update(level=3,
        message=f"File Updated with FUEL: {fuel}")

# %%
NexusBuilder.get_temporal_clusters()
# Out:
#  └ Calculating clustering attributes
#  └ No. of Timeslices configured= 24
#   └─ Representative days: [204, 206, 230, 296]

# %%
update_otoole_config

# %%
FUEL_set_file_path
# Out:
# PosixPath('data/clews_data/SETs/FUEL.csv')

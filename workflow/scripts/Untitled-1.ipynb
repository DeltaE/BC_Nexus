# %%
import os
scenario_files='/home/eliasinul/repositories/BC-CLEWS-Model/workflow/BCNexus_Scenarios/scenario_files'
contents = os.listdir(scenario_files)

# Filter out directories
SCENARIOS = sorted([item for item in contents if os.path.isdir(os.path.join(scenario_files, item))])

# %%
SCENARIOS
# Out:
# ['100-ELC',
#  '100-ELC-CO2reduction',
#  '100-ELC-NoGeo',
#  '100-ELC-Nuc(10GW)',
#  'AGG',
#  'Elias',
#  'REF',
#  'Sample']

# %%
import utilities as utils
dash_configs = utils.load_config('/home/eliasinul/repositories/BC-CLEWS-Model/config/dashboard.yaml')

# %%
info_SCENARIOS=dash_configs['info_SCENARIOS']

# %%
list(info_SCENARIOS.keys())
# Out:
# ['Sample',
#  'REF',
#  'AGG',
#  '100-ELC',
#  'aviation and HF-LND intensity Ave.',
#  '100-ELC-CO2reduction',
#  '100-ELC-Nuc(10GW)',
#  '100-ELC-NoGeo']

# %%
scenario

# %%
for scneario in SCENARIOS:
    if scneario not in info_SCENARIOS.keys():
        print("Info not found")
    else:
        print(f"{scneario}")
# Out:
# 100-ELC
# 100-ELC-CO2reduction
# 100-ELC-NoGeo
# 100-ELC-Nuc(10GW)
# AGG
# Info not found
# REF
# Sample

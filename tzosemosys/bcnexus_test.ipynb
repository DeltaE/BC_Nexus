# %%
from tz.osemosys import Model

# %%
my_model = Model.from_otoole_csv("data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_model = Model.from_otoole_csv("data")
#
# File ~/miniconda3/envs/tzosemosys/lib/python3.12/site-packages/tz/osemosys/schemas/compat/model.py:175, in RunSpecOtoole.from_otoole_csv(cls, root_dir, id)
#     173 impacts = Impact.from_otoole_csv(root_dir=root_dir)
#     174 regions = Region.from_otoole_csv(root_dir=root_dir)
# --> 175 technologies = Technology.from_otoole_csv(root_dir=root_dir)
#     176 storage = Storage.from_otoole_csv(root_dir=root_dir)
#     177 commodities = Commodity.from_otoole_csv(root_dir=root_dir)
#
# File ~/miniconda3/envs/tzosemosys/lib/python3.12/site-packages/tz/osemosys/schemas/compat/technology.py:182, in OtooleTechnology.from_otoole_csv(cls, root_dir)
#     180     for technology in dfs[df]["TECHNOLOGY"].unique():
# ...
